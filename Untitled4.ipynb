# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn import preprocessing
from scipy import stats
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("training_data.csv", low_memory=False)
df_o = df
df = df.drop(['PolicyNo', 'Policy_Zip_Code_Garaging_Location', ], axis=1)

# %%
target = df['Loss_Amount']
df = df.drop(df.columns[62:], axis=1)

# %%
import random

def make_portfolios(df):
    df = df.append(df, ignore_index=True)
    with_claims = []
    no_claims = []
    for i, r in enumerate(df['Loss_Amount']):
        if r > 0.0:
            with_claims.append(i)
        else:
            no_claims.append(i)
            
    random.shuffle(with_claims)
    random.shuffle(no_claims)
    portfolios = []
    i = 0
    while True:        
        size = np.random.choice(range(1, 5), p=[0.2, 0.3, 0.3, 0.2]) * 500
        loss_percent = np.random.choice(range(0, 5), p=[0.2]*5) * 5
        if loss_percent == 0:
            loss_percent = 2
                
        portfolio = []
        num_losses = int(loss_percent*(size/100))
#         print(i,'-',size, loss_percent, num_losses)
        i += 1
        for i in range(num_losses):
            try:
                portfolio.append(df.iloc[with_claims.pop()])
            except Exception as e:
#                 print('breaking,', e)
                break

        for i in range(size-num_losses):
            try:
                portfolio.append(df.iloc[no_claims.pop()])
            except Exception as e:
#                 print('breaking,', e)
                break        

        if len(with_claims) == 0 or len(no_claims) == 0:
#             if len(with_claims) != 0:
#                 while(len(with_claims) > 0):
#                     portfolio.append(df.iloc[with_claims.pop()])
#                 portfolios.append(pd.DataFrame(portfolio, columns=df.columns))
#             if len(no_claims) != 0:
#                 while(len(no_claims) > 0):
#                     portfolio.append(df.iloc[no_claims.pop()])
#                 portfolios.append(pd.DataFrame(portfolio, columns=df.columns))                
            break
            
        random.shuffle(portfolio)
        portfolios.append(pd.DataFrame(portfolio, columns=df.columns))
    return portfolios

# %%
vehicles = [v[:3] for v in df['Vehicle_Make_Description'].values]
vehicles = pd.DataFrame(data = vehicles)
df['Vehicle_Make_Description'] = vehicles
df.fillna(0)
# Out:
#        Policy_Company  Policy_Installment_Term       Policy_Billing_Code  \
# 0           Standard                         6  Direct Billed to Insured
# 1           Standard                         6  Direct Billed to Insured
# 2           Standard                         6  Direct Billed to Insured
# 3           Standard                         6  Direct Billed to Insured
# 4           Standard                         6  Direct Billed to Insured
# ...               ...                      ...                       ...
# 424426      Standard                         6  Direct Billed to Insured
# 424427      Standard                         6  Direct Billed to Insured
# 424428      Standard                         6  Direct Billed to Insured
# 424429      Preferred                        6  Direct Billed to Insured
# 424430      Standard                         6  Direct Billed to Insured
#
#        Policy_Method_Of_Payment Policy_Reinstatement_Fee_Indicator  \
# 0                      Pre-paid                                  N
# 1                      Pre-paid                                  N
# 2                      Pre-paid                                  N
# 3                      Pre-paid                                  N
# 4                      Pre-paid                                  N
# ...                         ...                                ...
# 424426                 Pre-paid                                  N
# 424427                 Pre-paid                                  N
# 424428              Installment                                  N
# 424429              Installment                                  N
# 424430              Installment                                  N
#
#         Vehicle_Territory  Vehicle_Make_Year Vehicle_Make_Description  \
# 0                      35               2004                      BUI
# 1                      35               1980                      CAD
# 2                      17               2005                      PON
# 3                      17               2005                      MER
# 4                      17               2005                      MER
# ...                   ...                ...                      ...
# 424426                 35               1999                      PON
# 424427                 31               2000                      NSS
# 424428                 35               1997                      PON
# 424429                 31               1998                      PON
# 424430                 31               2006                      CHE
#
#        Vehicle_Performance  Vehicle_New_Cost_Amount  ...  \
# 0                 Standard                       -1  ...
# 1                 Standard                       -1  ...
# 2                 Standard                       -1  ...
# 3                 Standard                       -1  ...
# 4                 Standard                       -1  ...
# ...                    ...                      ...  ...
# 424426            Standard                       -1  ...
# 424427            Standard                       -1  ...
# 424428            Standard                       -1  ...
# 424429            Standard                       -1  ...
# 424430            Standard                       -1  ...
#
#         EEA_Policy_Zip_Code_3  EEA_Policy_Tenure EEA_Agency_Type  \
# 0                         430               22.7        Standard
# 1                     Unknown               47.1       Preferred
# 2                         435               47.2    Non-standard
# 3                         435               46.7    Non-standard
# 4                         435               47.2    Non-standard
# ...                       ...                ...             ...
# 424426                    428                0.0       Preferred
# 424427                    436                0.0          Hybrid
# 424428                    424                0.0       Preferred
# 424429                    433                0.0    Non-standard
# 424430                    439                0.0    Non-standard
#
#         EEA_Packaged_Policy_Indicator  EEA_Full_Coverage_Indicator  \
# 0                                   N                            Y
# 1                                   N                            Y
# 2                                   N                            Y
# 3                                   Y                            Y
# 4                                   Y                            Y
# ...                               ...                          ...
# 424426                              N                            Y
# 424427                              Y                            N
# 424428                              N                            Y
# 424429                              N                            N
# 424430                              Y                            N
#
#        EEA_Prior_Bodily_Injury_Limit EEA_PolicyYear SYS_Renewed  \
# 0                            100-400           2006           Y
# 1                            100-200           2006           Y
# 2                            100-400           2006           Y
# 3                            40-100            2006           Y
# 4                            40-100            2006           Y
# ...                              ...            ...         ...
# 424426                             0           2006           Y
# 424427                       100-200           2006           Y
# 424428                       100-400           2006           N
# 424429                       40-100            2006           N
# 424430                             0           2006           Y
#
#         SYS_New_Business  Annual_Premium
# 0                      N          320.12
# 1                      N          259.70
# 2                      N          613.74
# 3                      N          541.66
# 4                      N          541.66
# ...                  ...             ...
# 424426                 Y          162.55
# 424427                 Y          117.13
# 424428                 Y          118.21
# 424429                 Y          103.93
# 424430                 Y          281.24
#
# [424431 rows x 62 columns]

# %%
from sklearn.preprocessing import LabelEncoder
df = df.dropna()
df = df.fillna(0)
le = LabelEncoder()
for col in df.columns:
    col = str(col)
    if str(df.loc[:,col].dtype) == 'object':
        le.fit(df.loc[:,col])
        df.loc[:,col] = le.transform(df.loc[:,col])
df
# Out:
#         Policy_Company  Policy_Installment_Term  Policy_Billing_Code  \
# 0                    1                        6                    0
# 1                    1                        6                    0
# 2                    1                        6                    0
# 3                    1                        6                    0
# 4                    1                        6                    0
# ...                ...                      ...                  ...
# 424424               1                        6                    0
# 424425               1                       12                    1
# 424427               1                        6                    0
# 424428               1                        6                    0
# 424429               0                        6                    0
#
#         Policy_Method_Of_Payment  Policy_Reinstatement_Fee_Indicator  \
# 0                              1                                   0
# 1                              1                                   0
# 2                              1                                   0
# 3                              1                                   0
# 4                              1                                   0
# ...                          ...                                 ...
# 424424                         1                                   0
# 424425                         1                                   0
# 424427                         1                                   0
# 424428                         0                                   0
# 424429                         0                                   0
#
#         Vehicle_Territory  Vehicle_Make_Year  Vehicle_Make_Description  \
# 0                      35               2004                        25
# 1                      35               1980                        31
# 2                      17               2005                       146
# 3                      17               2005                       124
# 4                      17               2005                       124
# ...                   ...                ...                       ...
# 424424                 31               2001                        57
# 424425                 36               2007                       138
# 424427                 31               2000                       138
# 424428                 35               1997                       146
# 424429                 31               1998                       146
#
#         Vehicle_Performance  Vehicle_New_Cost_Amount  ...  \
# 0                         4                       -1  ...
# 1                         4                       -1  ...
# 2                         4                       -1  ...
# 3                         4                       -1  ...
# 4                         4                       -1  ...
# ...                     ...                      ...  ...
# 424424                    4                       -1  ...
# 424425                    4                       -1  ...
# 424427                    4                       -1  ...
# 424428                    4                       -1  ...
# 424429                    4                       -1  ...
#
#         EEA_Policy_Zip_Code_3  EEA_Policy_Tenure  EEA_Agency_Type  \
# 0                          68               22.7                3
# 1                         198               47.1                2
# 2                          73               47.2                1
# 3                          73               46.7                1
# 4                          73               47.2                1
# ...                       ...                ...              ...
# 424424                     72                0.0                1
# 424425                     63                0.0                1
# 424427                     74                0.0                0
# 424428                     62                0.0                2
# 424429                     71                0.0                1
#
#         EEA_Packaged_Policy_Indicator  EEA_Full_Coverage_Indicator  \
# 0                                   0                            1
# 1                                   0                            1
# 2                                   0                            1
# 3                                   1                            1
# 4                                   1                            1
# ...                               ...                          ...
# 424424                              1                            1
# 424425                              1                            1
# 424427                              1                            0
# 424428                              0                            1
# 424429                              0                            0
#
#         EEA_Prior_Bodily_Injury_Limit  EEA_PolicyYear  SYS_Renewed  \
# 0                                   1            2006            1
# 1                                   0            2006            1
# 2                                   1            2006            1
# 3                                   5            2006            1
# 4                                   5            2006            1
# ...                               ...             ...          ...
# 424424                              2            2006            0
# 424425                              0            2006            1
# 424427                              0            2006            1
# 424428                              1            2006            0
# 424429                              5            2006            0
#
#         SYS_New_Business  Annual_Premium
# 0                      0          320.12
# 1                      0          259.70
# 2                      0          613.74
# 3                      0          541.66
# 4                      0          541.66
# ...                  ...             ...
# 424424                 1          649.55
# 424425                 1          541.26
# 424427                 1          117.13
# 424428                 1          118.21
# 424429                 1          103.93
#
# [407105 rows x 62 columns]

# %%
tem = df

pca = PCA(30).fit(df)
principal_cols = pca.transform(df)
df = pd.DataFrame(data = principal_cols)
df
# Out:
#                   0             1           2           3           4   \
# 0       49889.518672  -2930.385258 -356.549848  115.459756 -124.152320
# 1         -69.812810   -671.523706 -284.034909 -245.191946   61.412328
# 2       51123.808515  46053.880862 -461.687340 -195.804066  271.737974
# 3      -14989.009106   2706.425210 -265.858338   82.856452  201.038164
# 4      -14989.009103   2706.425426 -265.858456   82.840794  201.002109
# ...              ...           ...         ...         ...         ...
# 407100 -25111.469354  -2040.374307 -238.628694  377.329421  174.817989
# 407101  49990.962572   1069.505625 -362.548473  649.968639 -193.842418
# 407102      5.602921   2327.087610 -291.068743 -367.125966  -35.426157
# 407103  51123.795706  46053.291668 -461.828951 -105.513519 -357.644331
# 407104      5.592314   2327.058882 -291.111225 -373.973893  -46.988934
#
#                5          6          7           8         9   ...        20  \
#  311408 -0.002573 -0.290933 -0.100153  0.660932 -0.469421 -0.690032  0.539326
#  ...          ...       ...       ...       ...       ...       ...       ...
#  431729  1.361792  0.186109 -0.130541  0.479875 -0.399221 -0.801911  1.894057
#  357790  0.000169  0.405500 -0.103350  0.422547 -1.225040  1.581287 -0.068872
#  282660 -0.002592 -0.291148 -0.101070 -1.133135 -0.085745 -0.651142 -1.098053
#  669587 -0.683384 -0.181216 -0.086506  0.708216 -0.616829 -0.721938 -0.257024
#  465550 -0.002573 -0.290934 -0.100160  0.652900 -0.498738 -0.569116 -1.112764
#
#                 7         8         9  ...        22        23        24  \
#  794891 -2.022813  0.294653 -0.053919  ...  0.695155 -1.065815  1.461853
#  404409  1.003370 -0.273720 -0.723584  ... -0.226719 -0.673399 -0.426646
#  739943 -0.019708 -0.050205  0.292244  ... -0.571637  0.441653 -1.173661
#  629200  0.738888 -0.409438  5.896094  ...  0.159087 -0.194134  2.909843
#  311408 -0.124620  0.405020 -0.592849  ... -0.388449 -0.825970  0.336462
#  ...          ...       ...       ...  ...       ...       ...       ...
#  431729  0.786598  0.090363  0.054694  ... -0.048878 -0.702329 -0.158526
#  357790 -0.145619  0.426348 -0.775456  ...  1.155320 -0.992342 -1.019439
#  282660  0.786617 -0.912170 -0.337879  ...  0.415521 -1.034794  0.822996
#  669587  0.262485 -0.465274 -0.491343  ... -0.072563  0.363599 -0.435992
#  465550 -0.501921 -0.161307 -0.304600  ... -0.149849 -0.774310  0.139628
#
#                25        26        27        28        29  Loss_Amount  \
#  794891 -1.611457  0.074188 -0.532408 -1.736170  1.062992         0.00
#  404409 -0.304454  0.391123 -0.813883  1.017461  0.908398      8123.18
#  739943 -0.618281  1.142255  0.980619 -1.270910  0.402122         0.00
#  629200  0.903523 -0.627462 -0.803451 -0.038261  0.194835       710.51
#  311408  0.190681 -1.039510  2.060910  0.189964  0.075412         0.00
#  ...          ...       ...       ...       ...       ...          ...
#  431729 -1.121734 -0.910455 -1.416063 -1.433611  1.593554         0.00
#  357790  1.237985  0.325053 -0.450286 -0.849916 -0.664328         0.00
#  282660 -0.511141  1.004056  0.277829 -0.110428 -0.421496         0.00
#  669587  0.258464  0.676144  0.341281  0.527563  2.589892         0.00
#  465550  0.537280 -1.112848  1.601695  1.509304 -0.695022       255.42
#
#          Annual_Premium
#  794891          164.30
#  404409          629.64
#  739943          462.16
#  629200          474.88
#  311408          269.76
#  ...                ...
#  431729          262.88
#  357790          491.84
#  282660          398.11
#  669587          683.70
#  465550          685.82
#
#  [1000 rows x 32 columns]]

# %%
for p in portfolios:
    print(np.log(p['Loss_Amount'].sum()/p['Annual_Premium'].sum()))
# Out:
# 0.43313522233492924
# -1.5982332090390445
# 0.6547283114726534
# 0.2794788446437501
# -2.5116149792952602
# 1.126494653736041
# 1.1949210877294674
# -1.120174678444872
# -1.213348884899644
# 1.4947212875202582
# 0.7477619494276015
# 0.6768604449934588
# 0.6376275003535175
# -0.28405049777504837
# -0.7082931350112793
# 1.2159160835867358
# 1.151414539922788
# 0.36058389374089705
# -0.4040643037642208
# 0.31450258094911554
# 0.5772764673965901
# 0.9570770505595584
# -1.4087749613298377
# 1.1049444087248104
# 0.47635705339689327
# 1.4134206845647053
# -1.4197712567224299
# -0.5066391971290559
# 1.051484818580424
# 0.6949260715193224
# 0.3732053503218322
# 0.11497744960319188
# 1.137993086192833
# 1.0351288685539524
# 0.8581897009997907
# -0.3974161797649868
# 0.9177620464082746
# 0.6425142956248012
# 1.23417314481473
# 1.1244130036138182
# 1.4386229278999243
# 0.6682242634297487
# 0.5774270857670718
# -1.137235871035448
# 0.5126599658633791
# 0.76751624549326
# -1.1524935611614555
# 0.3836031128785649
# -0.5193220827539824
# -0.7753661639302366
# -1.3841870356059287
# 0.1800917730947584
# -0.9953402030115613
# -1.5763213624975483
# 1.1928487560967376
# 0.541030367050708
# -0.8382685284615483
# -0.747029373417334
# 0.8557755458440072
# 1.3221088763350493
# 1.0362410486367108
# 0.9800979443910841
# 0.6397142863216652
# 1.1804032611227802
# 0.4681191919942525
# 0.668433659461342
# 0.9010256295325786
# -0.7243577479350642
# -0.40165732239723473
# -2.055728011950619
# 0.41783287636816946
# -0.5218272349135982
# 0.9873318767244941
# -1.9100607353428458
# 1.1305538111226372
# 0.830373610652129
# -0.8724886538366451
# -0.2791764186020453
# 0.40743006461773157
# 1.0167271568715044
# 1.1841139811825088
# 0.9524291389772722
# 1.027163719033226
# -0.26709104889618646
# -0.8908139519245312
# -0.9602736851331029
# 0.6968543362215233
# 0.4758053624008618
# -1.1129089584795828
# 0.8026832094769317
# 0.134853188798162
# -0.21587717423673328
# 1.1819747373199643
# -0.8004361407707191
# 0.04614883918827802
# -0.4826199666016149
# 0.8151058329822916
# 1.0994653339053517
# -0.44937521305377265
# -0.7484389126231275
# -1.9497880493857913
# 0.26386508698096656
# 1.0195027970931758
# 0.9154934586535635
# -0.4525056402157051
# -2.0004981509553925
# 0.9739270822717886
# -2.0506089357144806
# -0.39559219306880233
# -0.25632094983942255
# 0.28160398665181186
# -1.6448690709917884
# -1.3490097044647797
# 0.1600249736618335
# -0.3164885305301167
# 0.23381978900002273
# -0.7213759813050029
# 1.1115000773173325
# -1.7095673130638172
# -0.49191983926730737
# -0.8551135178149339
# 0.45819808615924307
# -0.8037998798494881

# %%
def median_summarizer(df_t):
    values = df_t.median()
    n_df = pd.DataFrame([], columns=df_t.columns)
    return n_df.append(values, ignore_index=True)

def mean_summarizer(df_t):
    values = df_t.mean()
    n_df = pd.DataFrame([], columns=df_t.columns)
    return n_df.append(values, ignore_index=True)

def max_summarizer(df_t):
    values = df_t.max()
    n_df = pd.DataFrame([], columns=df_t.columns)
    return n_df.append(values, ignore_index=True)

def min_summarizer(df_t):
    values = df_t.min()
    n_df = pd.DataFrame([], columns=df_t.columns)
    return n_df.append(values, ignore_index=True)

def min_max_summarizer(df_t):
    values_min = df_t.min()
    values_max = df_t.max()
    values = (values_max + values_min)/2
    n_df = pd.DataFrame([])
    return n_df.append(values, ignore_index=True)

def std_dev_summarizer(df_t):
    values = df_t.std()
    n_df = pd.DataFrame([])
    return n_df.append(values, ignore_index=True)

def num_median_summarizer(df_t):
    df_med = median_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_med = df_med.values[0]
    values = [0] * len(df_med)
    for r in df_t.values:
        for i in range(len(r[:-2])):
            if r[i] > df_med[i]:
                values[i] += 1
    values = [v/len(df_t)*10 for v in values]
    #     print(len(values))
    n_df = pd.DataFrame([])
    return n_df.append([values], ignore_index=True)


def num_mean_std_dev_summarizer(df_t):
    df_std = std_dev_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_mean = mean_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_std = df_std.values[0]
    df_mean = df_mean.values[0]
    values = [0] * len(df_std)
    for r in df_t.values:
        for i in range(len(r[:-2])):
            if r[i] > df_mean[i] + df_std[i]:
                values[i] += 1
    values = [v/len(df_t)*10 for v in values]
#     print(len(values))
    n_df = pd.DataFrame([])
    return n_df.append([values], ignore_index=True)

def num_median_std_summarizer(df_t):
    df_med = median_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_std = num_mean_std_dev_summarizer(df_t)
    n_df = df_std
    n_df[[len(n_df.columns) + i for i in range(30)]] = df_med
    return n_df

def all_summarizer(df_t):
    df_std = std_dev_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_max = max_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_min = min_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_med = median_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    df_men = mean_summarizer(df_t.drop(['Loss_Amount', 'Annual_Premium'], axis=1))
    
    n_df = df_std
    n_df[[len(n_df.columns) + i for i in range(40)]] = df_max
    n_df[[len(n_df.columns) + i for i in range(40)]] = df_min
    n_df[[len(n_df.columns) + i for i in range(40)]] = df_med
    n_df[[len(n_df.columns) + i for i in range(40)]] = df_men
    return n_df
    

def summarize_portfolios(portfolios, summarizer=median_summarizer, convert_to_lr=False):
    summarized_portfolios = []
    flag = True
    for p in portfolios:
        portfolio = summarizer(p)
        if convert_to_lr:
            portfolio['lr'] = np.log(p['Loss_Amount'].sum()/p['Annual_Premium'].sum())
#             print(len(portfolio.columns))
            portfolio = portfolio.drop(['Loss_Amount', 'Annual_Premium'], axis=1)
        if flag:
            cols = portfolio.columns
            flag = False
        summarized_portfolios.append(portfolio)
        
    if cols is None:
        return None
    n_df = pd.DataFrame([], columns=cols)
    for p in summarized_portfolios:
        n_df = n_df.append(p, ignore_index=True)
#     print(n_df

#     pca_p = PCA().fit(n_df.drop('lr', axis=1))
#     principal_cols = pca_p.transform(n_df.drop('lr', axis=1))
#     n_df_t = pd.DataFrame(data = principal_cols)

    n_df_arr = StandardScaler().fit_transform(n_df.drop('lr', axis=1))
    n_df_t = pd.DataFrame(n_df_arr)
    n_df_t['lr'] = n_df['lr']
    
    return n_df_t

# %%
X = summarize_portfolios(portfolios, convert_to_lr=True)

# %%
# X = X.drop(X.columns[-3:-1], axis=1)
X['bias'] = 1
X
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.409592 -0.710875  1.527196  0.631820 -0.247952 -0.183021  1.024947
# 1   -0.379464 -0.700753 -0.676881  0.131153  0.074532 -0.574942 -0.922020
# 2   -0.421200 -0.702085  1.695258  0.179359 -0.044726  0.379365  0.320060
# 3   -0.390669 -0.712122 -0.548081  0.279337 -2.136973 -1.336947 -1.145076
# 4   -0.351766  1.214298 -0.396581  0.878952  0.679452  1.317687  0.113058
# ..        ...       ...       ...       ...       ...       ...       ...
# 294 -0.394120  1.215134 -0.173558  1.749865 -0.746526 -0.839177 -0.821387
# 295 -0.397470  1.213846 -0.389633 -0.563752  0.429729 -0.448630  0.148159
# 296 -0.411340 -0.703401  1.548896  0.413401 -0.373028 -0.301906 -0.573432
# 297  0.808891 -0.699476 -1.087731 -1.053775 -1.565736 -1.963737 -2.302807
# 298 -0.345529 -0.711740 -1.105193 -0.438695  1.010300 -0.207641 -0.494698
#
#             7         8         9  ...        22        23        24  \
# 0   -1.350597  0.777506 -0.829449  ... -0.577240  1.501547  0.542618
# 1   -1.266273 -1.222097  0.321548  ... -0.943673  0.493695 -1.227571
# 2   -1.582654  0.993779  0.447666  ...  0.901280  0.215752 -0.125858
# 3   -0.489898 -0.275004  2.167037  ... -1.070131  0.673319 -0.941043
# 4   -0.777496  0.202347 -0.462519  ... -0.656187 -1.248545  1.455260
# ..        ...       ...       ...  ...       ...       ...       ...
# 294  0.164880 -0.765095  1.623084  ...  1.673701 -2.525243 -0.336548
# 295  0.512017 -0.248624  0.167771  ...  0.093728  0.771015  0.695578
# 296 -0.244879 -0.552957  0.221378  ... -0.140937  0.014178 -0.672526
# 297  0.810987  2.178328 -0.323892  ...  0.056253  0.646901 -0.871386
# 298 -0.544452 -0.267695 -0.571420  ...  1.064898  0.618904  2.043066
#
#            25        26        27        28        29        lr  bias
# 0    0.257554 -0.043465 -0.055217  1.364515  1.135997 -0.106472     1
# 1    0.524235  0.474893 -0.836186  0.128006  0.395731  0.984523     1
# 2    0.230544  0.783917 -0.992171 -0.853663 -0.231392  1.295830     1
# 3   -1.808806  1.160855 -1.132184 -1.360795 -2.898765  0.771831     1
# 4    0.092885 -0.247401 -0.198614  0.675889  0.668782 -0.266506     1
# ..        ...       ...       ...       ...       ...       ...   ...
# 294  1.765406 -1.525438 -0.201655  1.363571  1.551032  0.912166     1
# 295 -0.347821  1.043979 -0.547180  0.353088  0.919605  1.056575     1
# 296  0.121252  0.108304 -1.199094 -0.460298  2.056707 -0.394292     1
# 297 -1.023795  2.127729  1.095881 -0.836799  2.002233  1.110874     1
# 298 -0.981167  0.722528 -1.302305  1.242793 -0.930219  0.912871     1
#
# [299 rows x 32 columns]

# %%
X.to_csv('training_30_med_new.csv')

# %%
import glob


import warnings
warnings.filterwarnings('ignore')


def get_testing_portfolios(folder_name=''):
    path = 'testing_portfolios' # use your path
    all_files = glob.glob(path + "/*.csv")
    print(len(all_files))
    portfolios = []
    i = 0
    for filename in all_files:
        i += 1
        p = pd.read_csv(filename, index_col=None, header=0)
        p = p.drop(['PolicyNo', 'Policy_Zip_Code_Garaging_Location',], axis=1)
        p = p.drop(p.columns[63:], axis=1)
        vehicles = [v[:3] for v in p['Vehicle_Make_Description'].values]
        vehicles = pd.DataFrame(data = vehicles)
        p['Vehicle_Make_Description'] = vehicles
        p.fillna(0)
        p = p.dropna()
        p = p.fillna(0)
        le = LabelEncoder()
        for col in p.columns:
            col = str(col)
            if str(p.loc[:,col].dtype) == 'object':
                le.fit(p.loc[:,col])
                p.loc[:,col] = le.transform(p.loc[:,col])
#         print(len(p.columns))
        principal_cols = pca.transform(p)
        p = pd.DataFrame(data = principal_cols)
        p_arr = StandardScaler().fit_transform(p)
        p = pd.DataFrame(p_arr)
        portfolios.append(p)
    return portfolios

# %%
t_ps = get_testing_portfolios()
# Out:
# 330

# %%
t_ps_c = summarize_portfolios(t_ps)
t_ps_c['bias'] = 1
t_ps_c
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.621982 -0.298273  0.281882  0.599631  0.669448  0.367683  1.245399
# 1    0.765643  1.027766  1.502794 -0.882471 -0.740213 -4.147565  0.329862
# 2    0.628801 -1.107779  0.147818 -0.990602  0.196765  1.012343 -1.554859
# 3    0.431330 -0.648174 -1.360527 -0.435569  0.236946 -1.005146 -0.342994
# 4    0.258706 -0.060407 -2.231860  0.588049 -0.255829 -0.702534 -0.113075
# ..        ...       ...       ...       ...       ...       ...       ...
# 325  4.909467 -1.058918 -0.392540  2.130054  0.353950 -1.905844  2.649345
# 326  0.537937 -0.789947  0.179381 -0.090540  0.492637 -0.484287  0.984171
# 327  0.074031  0.556150  0.156568  1.332659 -0.856384 -0.910096  0.113233
# 328 -0.508427  1.591598 -0.456132  0.095374  0.236238 -0.772120 -0.572306
# 329  1.952685  1.185912 -0.016558 -0.546320  0.528897  0.558630 -0.986546
#
#             7         8         9  ...        21        22        23  \
# 0   -1.369660  0.834526  1.232894  ...  0.028231  0.913523  0.165929
# 1    0.460164  2.206412 -1.095707  ... -0.767436  0.788470  0.260517
# 2   -0.102250 -0.925813 -0.531753  ...  1.316898 -1.157020  0.136469
# 3   -0.044962 -0.655949 -0.894795  ...  1.016365 -1.134012 -0.557816
# 4    1.221724 -0.717357  2.502954  ...  1.455225 -0.963825 -1.675995
# ..        ...       ...       ...  ...       ...       ...       ...
# 325  0.236232  2.482502 -0.251394  ... -2.038578  1.187220  3.097808
# 326  0.423487  0.117095  0.659822  ...  1.762736 -1.247042 -0.760006
# 327 -0.900282 -0.893082 -0.681379  ...  1.080291 -1.001807 -0.588149
# 328 -0.232016 -0.348379 -0.462866  ... -0.460041  0.571421  0.249965
# 329  0.137536 -0.200189  0.099667  ... -1.174928  1.027535  1.012999
#
#            24        25        26        27        28        29  bias
# 0   -0.089362 -0.798386  0.321671  0.070439 -1.632395 -1.763307     1
# 1    0.624205  0.071784  1.676725  0.385648 -2.969659  2.217599     1
# 2   -0.013615  0.349819 -0.168746  0.118549 -0.078057 -0.341580     1
# 3    0.225689  1.537978  0.318746  0.915323  0.582577  0.093911     1
# 4    0.213249 -0.194132  1.241554 -1.056794 -0.676642 -0.337977     1
# ..        ...       ...       ...       ...       ...       ...   ...
# 325  0.969541 -2.723754  1.230115  0.676140  0.087030 -0.792451     1
# 326  0.959522  0.841017  0.581765 -0.079124  0.589953  0.869548     1
# 327 -0.177202 -0.772906 -0.267278  0.102948 -0.401641  0.611214     1
# 328 -0.743688 -1.227430  0.167135  0.203137 -0.293574 -0.180031     1
# 329  0.107086  0.018468 -0.311754 -1.236116  0.297972 -0.016593     1
#
# [330 rows x 31 columns]

# %%
t_ps_c.to_csv('testing_30_med_new.csv')

# %%
X[[len(X.columns) + i - 1 for i in range(len(X.columns)-1)]] = X.drop('lr', axis=1)
